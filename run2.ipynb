# %%
# %run furhat_client/client_receive.py 
await main()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\bartender\Bart-Bartender\furhat_client\client_receive.py:121
#     115     await asyncio.gather(
#     116         handle_socket(sock, furhat, message_queue),
#     117         listen_and_process(furhat, chat, message_queue)
#     118     )
#     120 if __name__ == '__main__':
# --> 121     asyncio.run(main())
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
# ...
